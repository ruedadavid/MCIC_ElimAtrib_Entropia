# %%
import pandas as pd

# %%
file_name = 'data/Datos.xlsx'
data = pd.read_excel(file_name)

# %%
column_name = data.columns
data[column_name[1:13]][1:10]
# Out:
#       Style    Price  Rating  Size  Season NeckLine SleeveLength waiseline  \
# 1    Casual      Low     0.0     L  Summer   o-neck        Petal   natural
# 2   vintage     High     0.0     L  Automn   o-neck         full   natural
# 3     Brief  Average     4.6     L  Spring   o-neck         full   natural
# 4      cute      Low     4.5     M  Summer   o-neck    butterfly   natural
# 5  bohemian      Low     0.0     M  Summer   v-neck    sleevless    empire
# 6    Casual  Average     0.0    XL  Summer   o-neck         full       NaN
# 7   Novelty  Average     0.0  free  Automn   o-neck        short   natural
# 8     Flare  Average     0.0  free  Spring   v-neck        short    empire
# 9  bohemian      Low     0.0  free  Summer   v-neck    sleevless   natural
#
#         Material  FabricType  Decoration Pattern Type
# 1     microfiber         NaN     ruffles       animal
# 2       polyster         NaN         NaN        print
# 3           silk     chiffon  embroidary        print
# 4  chiffonfabric     chiffon         bow          dot
# 5            NaN         NaN         NaN        print
# 6         cotton         NaN         NaN        solid
# 7       polyster  broadcloth        lace          NaN
# 8         cotton  broadcloth     beading        solid
# 9          nylon     chiffon         NaN          NaN

# %%
len(data[1:])
# Out:
# 497
